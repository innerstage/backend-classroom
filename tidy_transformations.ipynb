# %% [markdown]
# # Transformaciones Tidy para los archivos fuente
#
# En este notebook mostraremos los pasos necesarios para llevar cada archivo al formato Tidy y luego unirlos bajo una lógica que siga siendo Tidy. Como primer paso, y para trabajar de forma más compacta, vamos a crear un comprensión de diccionario con DataFrames en vez de leer los archivos uno por uno, esta técnica puede facilitar la lectura del código y puede aumentar nuestra productividad.

# %%
import os
import pandas as pd

# %%
df = {i: pd.read_excel("data_source/chart{}.xlsx".format(i)) for i in range(1,9)}
df
# Out:
# {1:            region       censo acceso_tic  valor_porcentaje
#  0        AMAZONAS  Censo 2007  No accede          0.798952
#  1          ANCASH  Censo 2007  No accede          0.560716
#  2        APURIMAC  Censo 2007  No accede          0.818601
#  3        AREQUIPA  Censo 2007  No accede          0.392133
#  4        AYACUCHO  Censo 2007  No accede          0.785555
#  5       CAJAMARCA  Censo 2007  No accede          0.769990
#  6          CALLAO  Censo 2007  No accede          0.188507
#  7           CUSCO  Censo 2007  No accede          0.658221
#  8    HUANCAVELICA  Censo 2007  No accede          0.921439
#  9         HUANUCO  Censo 2007  No accede          0.781172
#  10            ICA  Censo 2007  No accede          0.351859
#  11          JUNIN  Censo 2007  No accede          0.604328
#  12    LA LIBERTAD  Censo 2007  No accede          0.445211
#  13     LAMBAYEQUE  Censo 2007  No accede          0.380144
#  14           LIMA  Censo 2007  No accede          0.207225
#  15         LORETO  Censo 2007  No accede          0.689274
#  16  MADRE DE DIOS  Censo 2007  No accede          0.551502
#  17       MOQUEGUA  Censo 2007  No accede          0.453288
#  18          PASCO  Censo 2007  No accede          0.681188
#  19          PIURA  Censo 2007  No accede          0.540316
#  20           PUNO  Censo 2007  No accede          0.747969
#  21     SAN MARTIN  Censo 2007  No accede          0.665492
#  22          TACNA  Censo 2007  No accede          0.383499
#  23         TUMBES  Censo 2007  No accede          0.361524
#  24        UCAYALI  Censo 2007  No accede          0.574158
#  25       AMAZONAS  Censo 2017  No accede          0.297306
#  26         ANCASH  Censo 2017  No accede          0.184059
#  27       APURIMAC  Censo 2017  No accede          0.283337
#  28       AREQUIPA  Censo 2017  No accede          0.070281
#  29       AYACUCHO  Censo 2017  No accede          0.215671
#  ..            ...         ...        ...               ...
#  70           PUNO  Censo 2007     Accede          0.252031
#  71     SAN MARTIN  Censo 2007     Accede          0.334508
#  72          TACNA  Censo 2007     Accede          0.616501
#  73         TUMBES  Censo 2007     Accede          0.638476
#  74        UCAYALI  Censo 2007     Accede          0.425842
#  75       AMAZONAS  Censo 2017     Accede          0.702694
#  76         ANCASH  Censo 2017     Accede          0.815941
#  77       APURIMAC  Censo 2017     Accede          0.716663
#  78       AREQUIPA  Censo 2017     Accede          0.929719
#  79       AYACUCHO  Censo 2017     Accede          0.784329
#  80      CAJAMARCA  Censo 2017     Accede          0.752793
#  81         CALLAO  Censo 2017     Accede          0.954115
#  82          CUSCO  Censo 2017     Accede          0.780567
#  83   HUANCAVELICA  Censo 2017     Accede          0.684959
#  84        HUANUCO  Censo 2017     Accede          0.749001
#  85            ICA  Censo 2017     Accede          0.904015
#  86          JUNIN  Censo 2017     Accede          0.819489
#  87    LA LIBERTAD  Censo 2017     Accede          0.869045
#  88     LAMBAYEQUE  Censo 2017     Accede          0.893025
#  89           LIMA  Censo 2017     Accede          0.955735
#  90         LORETO  Censo 2017     Accede          0.676635
#  91  MADRE DE DIOS  Censo 2017     Accede          0.899812
#  92       MOQUEGUA  Censo 2017     Accede          0.893699
#  93          PASCO  Censo 2017     Accede          0.782476
#  94          PIURA  Censo 2017     Accede          0.797587
#  95           PUNO  Censo 2017     Accede          0.716116
#  96     SAN MARTIN  Censo 2017     Accede          0.828432
#  97          TACNA  Censo 2017     Accede          0.917581
#  98         TUMBES  Censo 2017     Accede          0.890651
#  99        UCAYALI  Censo 2017     Accede          0.787724
#
#  [100 rows x 4 columns],
#  2:            region       censo conexión_internet  valor_porcentaje
#  0        AMAZONAS  Censo 2007            Accede          0.006741
#  1          ANCASH  Censo 2007            Accede          0.033885
#  2        APURIMAC  Censo 2007            Accede          0.009103
#  3        AREQUIPA  Censo 2007            Accede          0.068195
#  4        AYACUCHO  Censo 2007            Accede          0.014698
#  5       CAJAMARCA  Censo 2007            Accede          0.016411
#  6          CALLAO  Censo 2007            Accede          0.105678
#  7           CUSCO  Censo 2007            Accede          0.022354
#  8    HUANCAVELICA  Censo 2007            Accede          0.003679
#  9         HUANUCO  Censo 2007            Accede          0.014867
#  10            ICA  Censo 2007            Accede          0.042344
#  11          JUNIN  Censo 2007            Accede          0.021770
#  12    LA LIBERTAD  Censo 2007            Accede          0.056940
#  13     LAMBAYEQUE  Censo 2007            Accede          0.051979
#  14           LIMA  Censo 2007            Accede          0.145067
#  15         LORETO  Censo 2007            Accede          0.018768
#  16  MADRE DE DIOS  Censo 2007            Accede          0.009166
#  17       MOQUEGUA  Censo 2007            Accede          0.051203
#  18          PASCO  Censo 2007            Accede          0.012453
#  19          PIURA  Censo 2007            Accede          0.032529
#  20           PUNO  Censo 2007            Accede          0.009762
#  21     SAN MARTIN  Censo 2007            Accede          0.020530
#  22          TACNA  Censo 2007            Accede          0.059197
#  23         TUMBES  Censo 2007            Accede          0.025397
#  24        UCAYALI  Censo 2007            Accede          0.026793
#  25       AMAZONAS  Censo 2017            Accede          0.044549
#  26         ANCASH  Censo 2017            Accede          0.183262
#  27       APURIMAC  Censo 2017            Accede          0.089260
#  28       AREQUIPA  Censo 2017            Accede          0.328756
#  29       AYACUCHO  Censo 2017            Accede          0.104179
#  ..            ...         ...               ...               ...
#  70           PUNO  Censo 2007         No accede          0.990238
#  71     SAN MARTIN  Censo 2007         No accede          0.979470
#  72          TACNA  Censo 2007         No accede          0.940803
#  73         TUMBES  Censo 2007         No accede          0.974603
#  74        UCAYALI  Censo 2007         No accede          0.973207
#  75       AMAZONAS  Censo 2017         No accede          0.955451
#  76         ANCASH  Censo 2017         No accede          0.816738
#  77       APURIMAC  Censo 2017         No accede          0.910740
#  78       AREQUIPA  Censo 2017         No accede          0.671244
#  79       AYACUCHO  Censo 2017         No accede          0.895821
#  80      CAJAMARCA  Censo 2017         No accede          0.907128
#  81         CALLAO  Censo 2017         No accede          0.557939
#  82          CUSCO  Censo 2017         No accede          0.830811
#  83   HUANCAVELICA  Censo 2017         No accede          0.950669
#  84        HUANUCO  Censo 2017         No accede          0.891482
#  85            ICA  Censo 2017         No accede          0.725796
#  86          JUNIN  Censo 2017         No accede          0.836437
#  87    LA LIBERTAD  Censo 2017         No accede          0.727058
#  88     LAMBAYEQUE  Censo 2017         No accede          0.712713
#  89           LIMA  Censo 2017         No accede          0.527723
#  90         LORETO  Censo 2017         No accede          0.872624
#  91  MADRE DE DIOS  Censo 2017         No accede          0.835603
#  92       MOQUEGUA  Censo 2017         No accede          0.749805
#  93          PASCO  Censo 2017         No accede          0.904244
#  94          PIURA  Censo 2017         No accede          0.824649
#  95           PUNO  Censo 2017         No accede          0.925479
#  96     SAN MARTIN  Censo 2017         No accede          0.854997
#  97          TACNA  Censo 2017         No accede          0.707336
#  98         TUMBES  Censo 2017         No accede          0.788028
#  99        UCAYALI  Censo 2017         No accede          0.843304
#
#  [100 rows x 4 columns],
#  3:            region       censo accede_tv_cable  valor_porcentaje
#  0        AMAZONAS  Censo 2007          Accede          0.034497
#  1          ANCASH  Censo 2007          Accede          0.106276
#  2        APURIMAC  Censo 2007          Accede          0.032590
#  3        AREQUIPA  Censo 2007          Accede          0.123966
#  4        AYACUCHO  Censo 2007          Accede          0.025498
#  5       CAJAMARCA  Censo 2007          Accede          0.024539
#  6          CALLAO  Censo 2007          Accede          0.285722
#  7           CUSCO  Censo 2007          Accede          0.053531
#  8    HUANCAVELICA  Censo 2007          Accede          0.007490
#  9         HUANUCO  Censo 2007          Accede          0.038394
#  10            ICA  Censo 2007          Accede          0.074491
#  11          JUNIN  Censo 2007          Accede          0.054538
#  12    LA LIBERTAD  Censo 2007          Accede          0.126215
#  13     LAMBAYEQUE  Censo 2007          Accede          0.105706
#  14           LIMA  Censo 2007          Accede          0.315741
#  15         LORETO  Censo 2007          Accede          0.086341
#  16  MADRE DE DIOS  Censo 2007          Accede          0.139594
#  17       MOQUEGUA  Censo 2007          Accede          0.135380
#  18          PASCO  Censo 2007          Accede          0.093483
#  19          PIURA  Censo 2007          Accede          0.090255
#  20           PUNO  Censo 2007          Accede          0.015711
#  21     SAN MARTIN  Censo 2007          Accede          0.146108
#  22          TACNA  Censo 2007          Accede          0.073451
#  23         TUMBES  Censo 2007          Accede          0.123708
#  24        UCAYALI  Censo 2007          Accede          0.036979
#  25       AMAZONAS  Censo 2017          Accede          0.170784
#  26         ANCASH  Censo 2017          Accede          0.273368
#  27       APURIMAC  Censo 2017          Accede          0.131775
#  28       AREQUIPA  Censo 2017          Accede          0.349183
#  18        HUANUCO  Censo 2007     Teléfono fijo          0.072705
#  19        HUANUCO  Censo 2007  Teléfono celular          0.186897
#  20            ICA  Censo 2007     Teléfono fijo          0.236401
#  21            ICA  Censo 2007  Teléfono celular          0.551297
#  22          JUNIN  Censo 2007     Teléfono fijo          0.168921
#  23          JUNIN  Censo 2007  Teléfono celular          0.310654
#  24    LA LIBERTAD  Censo 2007     Teléfono fijo          0.297847
#  25    LA LIBERTAD  Censo 2007  Teléfono celular          0.434817
#  26     LAMBAYEQUE  Censo 2007     Teléfono fijo          0.281888
#  27     LAMBAYEQUE  Censo 2007  Teléfono celular          0.505045
#  28           LIMA  Censo 2007     Teléfono fijo          0.496351
#  29           LIMA  Censo 2007  Teléfono celular          0.623934
#  ..            ...         ...               ...               ...
#  70            ICA  Censo 2017     Teléfono fijo          0.178661
#  71            ICA  Censo 2017  Teléfono celular          0.876616
#  72          JUNIN  Censo 2017     Teléfono fijo          0.119578
#  73          JUNIN  Censo 2017  Teléfono celular          0.804628
#  74    LA LIBERTAD  Censo 2017     Teléfono fijo          0.216150
#  75    LA LIBERTAD  Censo 2017  Teléfono celular          0.844237
#  76     LAMBAYEQUE  Censo 2017     Teléfono fijo          0.215964
#  77     LAMBAYEQUE  Censo 2017  Teléfono celular          0.869645
#  78           LIMA  Censo 2017     Teléfono fijo          0.407266
#  79           LIMA  Censo 2017  Teléfono celular          0.921470
#  80         LORETO  Censo 2017     Teléfono fijo          0.100928
#  81         LORETO  Censo 2017  Teléfono celular          0.644421
#  82  MADRE DE DIOS  Censo 2017     Teléfono fijo          0.090892
#  83  MADRE DE DIOS  Censo 2017  Teléfono celular          0.880059
#  84       MOQUEGUA  Censo 2017     Teléfono fijo          0.143165
#  85       MOQUEGUA  Censo 2017  Teléfono celular          0.881004
#  86          PASCO  Censo 2017     Teléfono fijo          0.032819
#  87          PASCO  Censo 2017  Teléfono celular          0.767389
#  88          PIURA  Censo 2017     Teléfono fijo          0.122977
#  89          PIURA  Censo 2017  Teléfono celular          0.770718
#  90           PUNO  Censo 2017     Teléfono fijo          0.035742
#  91           PUNO  Censo 2017  Teléfono celular          0.713516
#  92     SAN MARTIN  Censo 2017     Teléfono fijo          0.070133
#  93     SAN MARTIN  Censo 2017  Teléfono celular          0.798230
#  94          TACNA  Censo 2017     Teléfono fijo          0.160493
#  95          TACNA  Censo 2017  Teléfono celular          0.908526
#  96         TUMBES  Censo 2017     Teléfono fijo          0.118806
#  97         TUMBES  Censo 2017  Teléfono celular          0.861401
#  98        UCAYALI  Censo 2017     Teléfono fijo          0.094106
#  99        UCAYALI  Censo 2017  Teléfono celular          0.769533
#
#  [100 rows x 4 columns],
#  5:            region empleo_equipos_informaticos  valor_porcentaje
#  0        AMAZONAS                      Empleó          0.836785
#  1        AMAZONAS                   No empleó          0.163215
#  2          ANCASH                      Empleó          0.780723
#  3          ANCASH                   No empleó          0.219277
# * Poner los nombres de región con mayúscula en la inicial y minúscula el resto del texto, usando el método title().
# * Añadiremos una columna que indique el origen de los datos (INEI o ENE).
# * Cambiar la columna de Censo para que utilice sólo el año como un número entero (menor espacio de almacenamiento en la base de datos), este año será usado en INEI o ENE.
# * Consideraremos una columna que indique la variable a medir, en este caso Acceso a TIC, y su valor (Accede, No accede), dejando la observación como "porcentaje".
#
# Estos serán los lineamientos generales para todos los archivos, en las tablas de ENE, el año siempre es 2017, justificamos esta decisión con un poco de información adicional del conjunto de datos:
#
# <img src="img/data_info.png" style="border:1px solid black">

# %% [markdown]
# ### 1. Transformaciones para chart1.xlsx

# %%
# Seleccionamos el DataFrame 1 en el diccionario, y utilizamos el método title() para modificar las regiones:
df[1]["region"] = df[1]["region"].str.title() 

# Creamos una columna para el origen de los datos con un valor único:
df[1]["data_origin"] = "INEI"

# Cambiamos el nombre de la columna "censo" por "year", luego conservamos sólo los últimos cuatro dígitos del 
# texto (para extraer el año) y finalmente cambiamos el tipo de la columna para que sea numérica:
df[1] = df[1].rename(columns={"censo":"year"})
df[1]["year"] = df[1]["year"].str[-4:] # [-4:] indica que se toma desde el cuarto carácter contando desde el final hacia adelante.
df[1]["year"] = df[1]["year"].astype(int) # Este paso se puede concatenar con el anterior usando .str[-4:].astype(int)

# Creamos una columna para la variable "acceso_tic" y su respuesta, en esta etapa seguiremos una estrategia distinta
# a cambiar el nombre, sólo crearemos una nueva columna copiando el contenido, y más adelante la descartaremos.
df[1]["variable"] = "Acceso a TIC"
df[1]["response"] = df[1]["acceso_tic"]

# Cambiamos el nombre de la columna "valor_porcentaje" y nos aseguramos de que esté como tipo float.
df[1] = df[1].rename(columns={"valor_porcentaje":"percentage"})
# df[1]["percentage"] = df[1]["percentage"].astype(float) 
#La línea no es realmente necesaria, puedes verificar al final que ya está en tipo float, pero la dejo de ejemplo.

# Seleccionamos sólo las columnas que queremos mantener
df[1] = df[1][["region", "data_origin", "year", "variable", "response", "percentage"]]

df[1].head()

# %% [markdown]
# La limpieza de los archivos 2, 3 y 4 será similar en estructura, pasaremos a limpiar el archivo 5 y a diseñar una abstracción posteriormente.
#
# ### 2. Transformaciones para chart5.xlsx

# %%
df[5]["region"] = df[5]["region"].str.title()

df[5]["data_origin"] = "ENE"

df[5]["year"] = 2017 # En este caso no es necesario cambiar el tipo a int, la creamos de esa forma.

df[5]["variable"] = "Empleó equipos informáticos"
df[5]["response"] = df[5]["empleo_equipos_informaticos"]

df[5] = df[5].rename(columns={"valor_porcentaje": "percentage"})

df[5] = df[5][["region", "data_origin", "year", "variable", "response", "percentage"]]

df[5].head()

# %% [markdown]
# ### 3. Abstracción
#
# Ahora que tenemos una idea general de los pasos para transformar ambas clases de archivos, podemos establecer las diferencias:
# * El origen de datos será distinto para ambos tipos de archivo.
# * Requieren líneas distintas para obtener el año.
# * El bloque de variable/respuesta será distinto para cada archivo.
#
# Para diseñar una transformación más abstracta, podemos hacer uso de diccionarios, funciones y estructuras de control que nos ayuden.

# %%
# Cargamos los archivos como al principio
df = {i: pd.read_excel("data_source/chart{}.xlsx".format(i)) for i in range(1,9)}

# De esta forma, cuando escriba variable_dict[1] entregará el valor "Acceso a TIC", por ejemplo.
variable_dict = { 
    1: "Acceso a TIC",
    2: "Acceso a Internet",
    3: "Acceso a TV Cable",
    4: "Tipo de Teléfono",
    5: "Empleó Equipos Informáticos",
    6: "Usó Internet",
    7: "Usó Internet para buscar Productos y Servicios",
    8: "Tuvo Problemas de Electricidad"
}

# Esta función entrega la posición de la columna que tiene el valor de response que necesitamos.
def get_response(i): 
    if i in [1,2,3,4]: # Si el archivo es de este tipo, el valor está en la tercera columna, o sea 2.
        return 2
    elif i in [5,6,7,8]: # Al saber que no hay más opciones para i, pudo ser "else: return 1", pero queda de ejemplo.
        return 1
# Hay otra forma incluso más corta de hacer esto, con una sola variable, pero dentro del ciclo que crearemos:
# response_col = 2 if i in [1,2,3,4] else 1

# Transformamos:
for i in range(1,9):
    df[i]["region"] = df[i]["region"].str.title()
    
    df[i]["data_origin"] = "INEI" if i in [1,2,3,4] else "ENE"
    
    if i in [1,2,3,4]:
        df[i] = df[i].rename(columns={"censo":"year"})
        df[i]["year"] = df[i]["year"].str[-4:] 
        df[i]["year"] = df[i]["year"].astype(int)
    else:
        df[i]["year"] = 2017
        
    df[i]["variable"] = variable_dict[i]
    df[i]["response"] = df[i].iloc[:, get_response(i)]
    
    df[i] = df[i].rename(columns={"valor_porcentaje": "percentage"})
    
    df[i] = df[i][["region", "data_origin", "year", "variable", "response", "percentage"]]
    
# Y finalmente concatenamos todas las DataFrames, para eso creamos una lista con ellas, sacándolas del diccionario:
df_list = [df[i] for i in range(1,9)]
df = pd.concat(df_list, ignore_index=True)

df.head()

# %% [markdown]
# Nuestro conjunto de datos ya se encuentra en formato Tidy. Adicionalmente podemos analizar las columnas generadas para asegurarnos de que el archivo final está bien.
#
# ### 4. Testing

# %%
# Deberíamos tener 25 regiones:
print("Regiones:", len(df["region"].unique()), "\n")

# Dos valores únicos para "data_origin" y "year"
print(df["data_origin"].value_counts(dropna=False), "\n")
print(df["year"].value_counts(dropna=False), "\n")

# 8 valores distintos para "variable"
print(df["variable"].value_counts(dropna=False), "\n")

# Valores distintos para "response", el resultado nos muestra que hay valores repetidos pero está bien.
# En el pipeline de Bamboo sería recomendable convertir esta respuesta binaria en 0 y 1.
print(df["response"].value_counts(dropna=False), "\n")

# Revisamos si algún porcentaje se escapa del intervalo [0,1]:
print(df[(df["percentage"]<=0) | (df["percentage"]>=1)], "\n")

# Y por último chequear que no hay valores nulos en ninguna columna:
print(df.isnull().any())

# %% [markdown]
# Con esto concluimos nuestras transformaciones, en la siguiente sección crearemos el pipeline de Bamboo.
