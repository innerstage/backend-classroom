# %% [markdown]
# # Análisis Exploratorio de Datos
#
# A continuación, analizaremos los archivos para contestar algunas preguntas básicas. El primer paso es importar las librerías necesarias, en particular `pandas` para trabajar con la data y explorarla, y `os` para contar con distintas funciones que nos permiten explorar el directorio.

# %%
import pandas as pd
import os

# %% [markdown]
# ### ¿Cuántos archivos tenemos en la carpeta?
#
# Desde nuestra ubicación, podemos abrir la carpeta con Python y hacer que nos muestre el contenido. El archivo `.DS_Store` es sólo un archivo de configuración local de Mac OS, al excluirlo podemos ver que existen 8 archivos en total. Finalmente, podemos utilizar comprensión de listas en Python para generar una lista de todos los nombres de archivo, mostraré varios ejemplos a continuación:

# %%
# Imprime una lista de los archivos en el directorio especificado.
print("Todos los archivos: ", os.listdir("data_source"))

# Genera los nombres de archivo siguiendo un patrón sencillo.
filenames = ["chart{}.xlsx".format(i) for i in range(1,9)]
print("\nPrimera forma:\nfilenames = ", filenames)

# Comprensión de lista excluyendo un valor, y luego ordenando con sorted(). 
# Si los archivos no tuviesen un patrón claro, este método es más útil.
filenames = sorted([f for f in os.listdir("data_source") if f != ".DS_Store"])
print("\nSegunda forma:\nfilenames = ", filenames)

# Comprensión de lista tomando sólo los archivos .xlsx y ordenando con sorted().
# Muy útil si existen distintas extensiones de archivo y quieres extraer alguna específica.
filenames = sorted([f for f in os.listdir("data_source") if ".xlsx" in f])
print("\nTercera forma:\nfilenames = ", filenames)
# Out:
# Todos los archivos:  ['chart6.xlsx', '.DS_Store', 'chart7.xlsx', 'chart1.xlsx', 'chart2.xlsx', 'chart3.xlsx', 'chart4.xlsx', 'chart8.xlsx', 'chart5.xlsx']
#
# Primera forma:
# filenames =  ['chart1.xlsx', 'chart2.xlsx', 'chart3.xlsx', 'chart4.xlsx', 'chart5.xlsx', 'chart6.xlsx', 'chart7.xlsx', 'chart8.xlsx']
#
# Segunda forma:
# filenames =  ['chart1.xlsx', 'chart2.xlsx', 'chart3.xlsx', 'chart4.xlsx', 'chart5.xlsx', 'chart6.xlsx', 'chart7.xlsx', 'chart8.xlsx']
#
# Tercera forma:
# filenames =  ['chart1.xlsx', 'chart2.xlsx', 'chart3.xlsx', 'chart4.xlsx', 'chart5.xlsx', 'chart6.xlsx', 'chart7.xlsx', 'chart8.xlsx']

# %% [markdown]
# ### ¿Qué formato poseen? ¿Están en el mismo formato? ¿Los formatos pueden ser leídos directamente por `pandas`?
#
# En este caso, todos los archivos poseen el mismo formato (`.xlsx`), y pueden ser leídos directamente por `pandas`. Así como cualquiera de las siguientes extensiones:
#
#
#
# | Format Type | Data Description | Reader | Writer |
# |:---|:---|:---|:---|
# | text | CSV | read_csv | to_csv |
# | text | Fixed-Width Text File | read_fwf |  |
# | text | JSON | read_json | to_json |
# | text | HTML | read_html | to_html |
# | text | Local clipboard | read_clipboard | to_clipboard |
# | ---  | MS Excel | read_excel | to_excel |
# | binary | OpenDocument | read_excel |  |
# | binary | HDF5 Format | read_hdf | to_hdf |
# | binary | Feather Format | read_feather | to_feather |
# | binary | Parquet Format | read_parquet | to_parquet |
# | binary | ORC Format | read_orc |  |
# | binary | Msgpack | read_msgpack | to_msgpack |
# | binary | Stata | read_stata | to_stata |
# | binary | SAS | read_sas |  |
# | binary | SPSS | read_spss |  |
# | binary | Python Pickle Format | read_pickle | to_pickle |
# | SQL | SQL | read_sql | to_sql |
# | SQL | Google BigQuery | read_gbq | to_gbq |

# %% [markdown]
# ### ¿Cuántas filas y columnas posee cada archivo?
#
# Para analizar cada archivo, hacemos uso de la lista `filenames` que creamos previamente, y podemos imprimir algunas filas e información de cada uno. Ahora tenemos una idea sobre la estructura de cada archivo.

# %%
for f in filenames: # f tomará el valor de cada nombre de archivo.
    print("\nARCHIVO: ", f) # Imprimimos el nombre del archivo para referencia.
    df = pd.read_excel("data_source/" + f) # Debemos agregar "data_source/" para que busque el archivo en la carpeta.
    print("\n", df.head(), "\n")
    print("\n", df.info())
# Out:
# ARCHIVO:  chart1.xlsx
#
#       region       censo acceso_tic  valor_porcentaje
# 0  AMAZONAS  Censo 2007  No accede          0.798952
# 1    ANCASH  Censo 2007  No accede          0.560716
# 2  APURIMAC  Censo 2007  No accede          0.818601
# 3  AREQUIPA  Censo 2007  No accede          0.392133
# 4  AYACUCHO  Censo 2007  No accede          0.785555
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
# region              100 non-null object
# censo               100 non-null object
# acceso_tic          100 non-null object
# valor_porcentaje    100 non-null float64
# dtypes: float64(1), object(3)
# memory usage: 3.2+ KB
#
#  None
#
# ARCHIVO:  chart2.xlsx
#
#       region       censo conexión_internet  valor_porcentaje
# 0  AMAZONAS  Censo 2007            Accede          0.006741
# 1    ANCASH  Censo 2007            Accede          0.033885
# 2  APURIMAC  Censo 2007            Accede          0.009103
# 3  AREQUIPA  Censo 2007            Accede          0.068195
# 4  AYACUCHO  Censo 2007            Accede          0.014698
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
# region               100 non-null object
# censo                100 non-null object
# conexión_internet    100 non-null object
# valor_porcentaje     100 non-null float64
# dtypes: float64(1), object(3)
# memory usage: 3.2+ KB
#
#  None
#
# ARCHIVO:  chart3.xlsx
#
#       region       censo accede_tv_cable  valor_porcentaje
# 0  AMAZONAS  Censo 2007          Accede          0.034497
# 1    ANCASH  Censo 2007          Accede          0.106276
# 2  APURIMAC  Censo 2007          Accede          0.032590
# 3  AREQUIPA  Censo 2007          Accede          0.123966
# 4  AYACUCHO  Censo 2007          Accede          0.025498
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
# region              100 non-null object
# censo               100 non-null object
# accede_tv_cable     100 non-null object
# valor_porcentaje    100 non-null float64
# dtypes: float64(1), object(3)
# memory usage: 3.2+ KB
#
#  None
#
# ARCHIVO:  chart4.xlsx
#
#       region       censo     tipo_telefono  valor_porcentaje
# 0  AMAZONAS  Censo 2007     Teléfono fijo          0.050361
# 1  AMAZONAS  Censo 2007  Teléfono celular          0.176800
# 2    ANCASH  Censo 2007     Teléfono fijo          0.201152
# 3    ANCASH  Censo 2007  Teléfono celular          0.349218
# 4  APURIMAC  Censo 2007     Teléfono fijo          0.049199
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
# region              100 non-null object
# censo               100 non-null object
# tipo_telefono       100 non-null object
# valor_porcentaje    100 non-null float64
# dtypes: float64(1), object(3)
# memory usage: 3.2+ KB
#
#  None
#
# ARCHIVO:  chart5.xlsx
#
#       region empleo_equipos_informaticos  valor_porcentaje
# 0  AMAZONAS                      Empleó          0.836785
# 1  AMAZONAS                   No empleó          0.163215
# 2    ANCASH                      Empleó          0.780723
# 3    ANCASH                   No empleó          0.219277
# 4  APURIMAC                      Empleó          0.870490
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
# region                         50 non-null object
# empleo_equipos_informaticos    50 non-null object
# valor_porcentaje               50 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 1.2+ KB
#
#  None
#
# ARCHIVO:  chart6.xlsx
#
#       region uso_internet  valor_porcentaje
# 0  AMAZONAS          Usó          0.935132
# 1  AMAZONAS       No usó          0.064868
# 2    ANCASH          Usó          0.914582
# 3    ANCASH       No usó          0.085418
# 4  APURIMAC          Usó          0.904484
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
# region              50 non-null object
# uso_internet        50 non-null object
# valor_porcentaje    50 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 1.2+ KB
#
#  None
#
# ARCHIVO:  chart7.xlsx
#
#       region uso_internet  valor_porcentaje
# 0  AMAZONAS          Usó          0.594095
# 1    ANCASH          Usó          0.480453
# 2  APURIMAC          Usó          0.643770
# 3  AREQUIPA          Usó          0.469783
# 4  AYACUCHO          Usó          0.392023
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
# region              50 non-null object
# uso_internet        50 non-null object
# valor_porcentaje    50 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 1.2+ KB
#
#  None
#
# ARCHIVO:  chart8.xlsx
#
#       region problemas_electricidad  valor_porcentaje
# 0  AMAZONAS         Tuvo problemas          0.652641
# 1  AMAZONAS      No tuvo problemas          0.347359
# 2    ANCASH         Tuvo problemas          0.383275
# 3    ANCASH      No tuvo problemas          0.616725
# 4  APURIMAC         Tuvo problemas          0.647401
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
# region                    50 non-null object
# problemas_electricidad    50 non-null object
# valor_porcentaje          50 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 1.2+ KB
#
#  None

# %% [markdown]
# ### ¿Tenemos valores nulos (`NaN`) en ciertas columnas? ¿Cuál es la mejor estrategia para este conjunto de datos?
#
# En este caso, vamos a analizar los archivos uno por uno, testeando para encontrar valores nulos o inconsistencias en las columnas.

# %%
for f in filenames:
    print("\nARCHIVO: ", f)
    df = pd.read_excel("data_source/" + f)
    print(df.isnull().any()) # Imprimimos en pantalla qué columnas poseen valores nulos.
# Out:
# ARCHIVO:  chart1.xlsx
# region              False
# censo               False
# acceso_tic          False
# valor_porcentaje    False
# dtype: bool
#
# ARCHIVO:  chart2.xlsx
# region               False
# censo                False
# conexión_internet    False
# valor_porcentaje     False
# dtype: bool
#
# ARCHIVO:  chart3.xlsx
# region              False
# censo               False
# accede_tv_cable     False
# valor_porcentaje    False
# dtype: bool
#
# ARCHIVO:  chart4.xlsx
# region              False
# censo               False
# tipo_telefono       False
# valor_porcentaje    False
# dtype: bool
#
# ARCHIVO:  chart5.xlsx
# region                         False
# empleo_equipos_informaticos    False
# valor_porcentaje               False
# dtype: bool
#
# ARCHIVO:  chart6.xlsx
# region              False
# uso_internet        False
# valor_porcentaje    False
# dtype: bool
#
# ARCHIVO:  chart7.xlsx
# region              False
# uso_internet        False
# valor_porcentaje    False
# dtype: bool
#
# ARCHIVO:  chart8.xlsx
# region                    False
# problemas_electricidad    False
# valor_porcentaje          False
# dtype: bool

# %% [markdown]
# También es posible revisar los valores únicos de cada columna en cada DataFrame generado. El proceso puede ser tedioso y puede omitirse, pero se debe volver a él si es que hay errores en el futuro.

# %%
for f in filenames:
    print("\nARCHIVO: ", f)
    df = pd.read_excel("data_source/" + f)
    for c in df.keys():
        print("\nCOLUMNA: ", c)
        print(df[c].value_counts(dropna=False)) 

# Imprimimos en pantalla los valores posibles en cada columna, se agrega dropna=False para poder revisar si hay NaNs.
# Out:
# ARCHIVO:  chart1.xlsx
#
# COLUMNA:  region
# PUNO             4
# CAJAMARCA        4
# JUNIN            4
# LA LIBERTAD      4
# PASCO            4
# TUMBES           4
# LORETO           4
# AMAZONAS         4
# MOQUEGUA         4
# PIURA            4
# UCAYALI          4
# HUANUCO          4
# AYACUCHO         4
# CUSCO            4
# APURIMAC         4
# LIMA             4
# TACNA            4
# ANCASH           4
# MADRE DE DIOS    4
# AREQUIPA         4
# HUANCAVELICA     4
# CALLAO           4
# LAMBAYEQUE       4
# SAN MARTIN       4
# ICA              4
# Name: region, dtype: int64
#
# COLUMNA:  censo
# Censo 2017    50
# Censo 2007    50
# Name: censo, dtype: int64
#
# COLUMNA:  acceso_tic
# Accede       50
# No accede    50
# Name: acceso_tic, dtype: int64
#
# COLUMNA:  valor_porcentaje
# 0.181399    1
# 0.351859    1
# 0.546712    1
# 0.045885    1
# 0.819489    1
# 0.283884    1
# 0.207225    1
# 0.681188    1
# 0.341779    1
# 0.929719    1
# 0.781172    1
# 0.202413    1
# 0.078561    1
# 0.818601    1
# 0.676635    1
# 0.689274    1
# 0.214445    1
# 0.215671    1
# 0.716663    1
# 0.554789    1
# 0.607867    1
# 0.392133    1
# 0.380144    1
# 0.540316    1
# 0.811493    1
# 0.448498    1
# 0.130955    1
# 0.787724    1
# 0.785555    1
# 0.459684    1
#            ..
# 0.297306    1
# 0.702694    1
# 0.445211    1
# 0.815941    1
# 0.082419    1
# 0.752793    1
# 0.893699    1
# 0.230010    1
# 0.560716    1
# 0.954115    1
# 0.638476    1
# 0.917581    1
# 0.395672    1
# 0.247207    1
# 0.283337    1
# 0.217524    1
# 0.551502    1
# 0.218828    1
# 0.250999    1
# 0.106301    1
# 0.716116    1
# 0.334508    1
# 0.318812    1
# 0.798952    1
# 0.904015    1
# 0.171568    1
# 0.184059    1
# 0.252031    1
# 0.780567    1
# 0.890651    1
# Name: valor_porcentaje, Length: 100, dtype: int64
#
# ARCHIVO:  chart2.xlsx
#
# COLUMNA:  region
# PUNO             4
# CAJAMARCA        4
# JUNIN            4
# LA LIBERTAD      4
# PASCO            4
# TUMBES           4
# LORETO           4
# AMAZONAS         4
# MOQUEGUA         4
# PIURA            4
# UCAYALI          4
# HUANUCO          4
# AYACUCHO         4
# CUSCO            4
# APURIMAC         4
# LIMA             4
# TACNA            4
# ANCASH           4
# MADRE DE DIOS    4
# AREQUIPA         4
# HUANCAVELICA     4
# CALLAO           4
# LAMBAYEQUE       4
# SAN MARTIN       4
# ICA              4
# Name: region, dtype: int64
#
# COLUMNA:  censo
# Censo 2017    50
# Censo 2007    50
# Name: censo, dtype: int64
#
# COLUMNA:  conexión_internet
# Accede       50
# No accede    50
# Name: conexión_internet, dtype: int64
#
# COLUMNA:  valor_porcentaje
# 0
# 0.093483    1
# 0.876292    1
# 0.927541    1
# 0.829216    1
# 0.848956    1
# 0.062258    1
# 0.285722    1
# 0.073451    1
# 0.679552    1
# 0.946469    1
# 0.146108    1
# 0.451730    1
# 0.961606    1
# Name: valor_porcentaje, Length: 100, dtype: int64
#
# ARCHIVO:  chart4.xlsx
#
# COLUMNA:  region
# PUNO             4
# CAJAMARCA        4
# JUNIN            4
# LA LIBERTAD      4
# PASCO            4
# TUMBES           4
# LORETO           4
# AMAZONAS         4
# MOQUEGUA         4
# PIURA            4
# UCAYALI          4
# HUANUCO          4
# AYACUCHO         4
# CUSCO            4
# APURIMAC         4
# LIMA             4
# TACNA            4
# ANCASH           4
# MADRE DE DIOS    4
# AREQUIPA         4
# HUANCAVELICA     4
# CALLAO           4
# LAMBAYEQUE       4
# SAN MARTIN       4
# ICA              4
# Name: region, dtype: int64
#
# COLUMNA:  censo
# Censo 2017    50
# Censo 2007    50
# Name: censo, dtype: int64
#
# COLUMNA:  tipo_telefono
# Teléfono celular    50
# Teléfono fijo       50
# Name: tipo_telefono, dtype: int64
#
# COLUMNA:  valor_porcentaje
# 0.055703    1
# 0.767389    1
# 0.070133    1
# 0.144749    1
# 0.796012    1
# 0.629816    1
# 0.178661    1
# 0.066423    1
# 0.029455    1
# 0.204629    1
# 0.143165    1
# 0.061401    1
# 0.072591    1
# 0.049199    1
# 0.407266    1
# 0.861401    1
# 0.116219    1
# 0.019506    1
# 0.012229    1
# 0.776488    1
# 0.434817    1
# 0.216150    1
# 0.798230    1
# 0.103186    1
# 0.693948    1
# 0.844237    1
# 0.285609    1
# 0.190783    1
# 0.912771    1
# 0.292101    1
#            ..
# 0.029608    1
# 0.048662    1
# 0.201152    1
# 0.215964    1
# 0.032819    1
# 0.050361    1
# 0.105918    1
# 0.183246    1
# 0.566083    1
# 0.236401    1
# 0.496351    1
# 0.349218    1
# 0.623934    1
# 0.738851    1
# 0.168921    1
# 0.881004    1
# 0.713516    1
# 0.090892    1
# 0.217009    1
# 0.046006    1
# 0.487790    1
# 0.281436    1
# 0.681545    1
# 0.176800    1
# 0.505859    1
# 0.205588    1
# 0.921470    1
# 0.551297    1
# 0.869645    1
# 0.235975    1
# Name: valor_porcentaje, Length: 100, dtype: int64
#
# ARCHIVO:  chart5.xlsx
#
# COLUMNA:  region
# PUNO             2
# CAJAMARCA        2
# JUNIN            2
# LA LIBERTAD      2
# PASCO            2
# TUMBES           2
# LORETO           2
# AMAZONAS         2
# MOQUEGUA         2
# PIURA            2
# UCAYALI          2
# HUANUCO          2
# AYACUCHO         2
# CUSCO            2
# APURIMAC         2
# LIMA             2
# TACNA            2
# ANCASH           2
# MADRE DE DIOS    2
# AREQUIPA         2
# HUANCAVELICA     2
# CALLAO           2
# LAMBAYEQUE       2
# SAN MARTIN       2
# ICA              2
# Name: region, dtype: int64
#
# COLUMNA:  empleo_equipos_informaticos
# Empleó       25
# No empleó    25
# Name: empleo_equipos_informaticos, dtype: int64
#
# COLUMNA:  valor_porcentaje
# 0
dtype: int64
#
# COLUMNA:  valor_porcentaje
# 0.519547    1
# 0.578431    1
# 0.410556    1
# 0.451808    1
# 0.365968    1
# 0.643770    1
# 0.594095    1
# 0.447626    1
# 0.451748    1
# 0.556786    1
# 0.548192    1
# 0.392023    1
# 0.503175    1
# 0.577341    1
# 0.434892    1
# 0.552374    1
# 0.453188    1
# 0.607977    1
# 0.520530    1
# 0.565108    1
# 0.484969    1
# 0.495057    1
# 0.546812    1
# 0.449605    1
# 0.504943    1
# 0.530217    1
# 0.538576    1
# 0.443214    1
# 0.421569    1
# 0.815999    1
# 0.480453    1
# 0.496825    1
# 0.526157    1
# 0.443807    1
# 0.422659    1
# 0.469783    1
# 0.479470    1
# 0.634032    1
# 0.473843    1
# 0.548252    1
# 0.356230    1
# 0.424272    1
# 0.461424    1
# 0.589444    1
# 0.405905    1
# 0.184001    1
# 0.515031    1
# 0.556193    1
# 0.575728    1
# 0.550395    1
# Name: valor_porcentaje, dtype: int64
#
# ARCHIVO:  chart8.xlsx
#
# COLUMNA:  region
# PUNO             2
# CAJAMARCA        2
# JUNIN            2
# LA LIBERTAD      2
# PASCO            2
# TUMBES           2
# LORETO           2
# AMAZONAS         2
# MOQUEGUA         2
# PIURA            2
# UCAYALI          2
# HUANUCO          2
# AYACUCHO         2
# CUSCO            2
# APURIMAC         2
# LIMA             2
# TACNA            2
# ANCASH           2
# MADRE DE DIOS    2
# AREQUIPA         2
# HUANCAVELICA     2
# CALLAO           2
# LAMBAYEQUE       2
# SAN MARTIN       2
# ICA              2
# Name: region, dtype: int64
#
# COLUMNA:  problemas_electricidad
# No tuvo problemas    25
# Tuvo problemas       25
# Name: problemas_electricidad, dtype: int64
#
# COLUMNA:  valor_porcentaje
# 0.661259    1
# 0.463164    1
# 0.531925    1
# 0.777694    1
# 0.616725    1
# 0.476447    1
# 0.297605    1
# 0.536836    1
# 0.575028    1
# 0.237734    1
# 0.347359    1
# 0.475219    1
# 0.458523    1
# 0.776215    1
# 0.273962    1
# 0.725409    1
# 0.468075    1
# 0.246509    1
# 0.419922    1
# 0.652641    1
# 0.349362    1
# 0.726038    1
# 0.541477    1
# 0.523553    1
# 0.274591    1
# 0.495439    1
# 0.268804    1
# 0.762266    1
# 0.381594    1
# 0.702395    1
# 0.338741    1
# 0.539272    1
# 0.647401    1
# 0.731196    1
# 0.560999    1
# 0.460728    1
# 0.439001    1
# 0.753491    1
# 0.383275    1
# 0.223785    1
# 0.524059    1
# 0.504561    1
# 0.352599    1
# 0.524781    1
# 0.424972    1
# 0.222306    1
# 0.580078    1
# 0.650638    1
# 0.475941    1
# 0.618406    1
# Name: valor_porcentaje, dtype: int64

# %% [markdown]
# Encontramos que ninguno de los archivos posee valores nulos y logramos entender los aspectos más importantes de la estructura en los archivos. En la siguiente etapa hablaremos de Tidy Data y cómo lograr unir estos archivos.
